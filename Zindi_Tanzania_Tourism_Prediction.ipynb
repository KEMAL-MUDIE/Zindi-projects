# %% [markdown]
# <a href="https://colab.research.google.com/github/KEMAL-MUDIE/Zindi-projects/blob/main/Zindi_Tanzania_Tourism_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
np.random.seed(123)
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
np.random.seed(123)
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Import data
train = pd.read_csv("/content/Train.csv")
test = pd.read_csv('/content/Test .csv')

# %%
train.head()
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 3  tour_1002  UNITED KINGDOM     25-44             Spouse           1.0
# 4  tour_1004           CHINA      1-24                NaN           1.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
# 3         1.0            Leisure and Holidays  Wildlife tourism
# 4         0.0            Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement  ... package_transport_tz  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            3695 non-null   object
#  4   total_female           4806 non-null   float64
#  5   total_male             4804 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
train.describe()
# Out:
#        total_female   total_male  night_mainland  night_zanzibar    total_cost
# count   4806.000000  4804.000000     4809.000000     4809.000000  4.809000e+03
# mean       0.926758     1.009575        8.488043        2.304429  8.114389e+06
# std        1.288242     1.138865       10.427624        4.227080  1.222490e+07
# min        0.000000     0.000000        0.000000        0.000000  4.900000e+04
# 25%        0.000000     1.000000        3.000000        0.000000  8.121750e+05
# 50%        1.000000     1.000000        6.000000        0.000000  3.397875e+06
# 75%        1.000000     1.000000       11.000000        4.000000  9.945000e+06
# max       49.000000    44.000000      145.000000       61.000000  9.953288e+07

# %%
train.shape
# Out:
# (4809, 23)

# %%
test.shape
# Out:
# (1601, 22)

# %%
test.head()
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_1       AUSTRALIA     45-64             Spouse           1.0
# 1   tour_100    SOUTH AFRICA     25-44  Friends/Relatives           0.0
# 2  tour_1001         GERMANY     25-44  Friends/Relatives           3.0
# 3  tour_1006          CANADA    24-Jan  Friends/Relatives           2.0
# 4  tour_1009  UNITED KINGDOM     45-64  Friends/Relatives           2.0
#
#    total_male               purpose     main_activity  \
# 0         1.0  Leisure and Holidays  Wildlife tourism
# 1         4.0              Business  Wildlife tourism
# 2         0.0  Leisure and Holidays     Beach tourism
# 3         0.0  Leisure and Holidays  Cultural tourism
# 4         2.0  Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement  ... package_food  \
# 0  Travel, agent, tour operator     Package Tour  ...          Yes
# 1       Tanzania Mission Abroad     Package Tour  ...           No
# ...

# %%
train.isnull().sum()
# Out:
# ID                          0
# country                     0
# age_group                   0
# travel_with              1114
# total_female                3
# total_male                  5
# purpose                     0
# main_activity               0
# info_source                 0
# tour_arrangement            0
# package_transport_int       0
# package_accomodation        0
# package_food                0
# package_transport_tz        0
# package_sightseeing         0
# package_guided_tour         0
# package_insurance           0
# night_mainland              0
# night_zanzibar              0
# payment_mode                0
# first_trip_tz               0
# most_impressing           313
# total_cost                  0
# dtype: int64

# %%
print(train['total_female'].value_counts())
print("="*50)
train['total_male'].value_counts()
# Out:
# 1.0     2418
# 0.0     1669
# 2.0      463
# 3.0      144
# 4.0       46
# 5.0       25
# 6.0       15
# 7.0       10
# 10.0       4
# 9.0        4
# 12.0       3
# 11.0       3
# 15.0       1
# 49.0       1
# Name: total_female, dtype: int64
# ...
# 1.0     2961
# 0.0     1137
# 2.0      478
# 3.0      139
# 4.0       46
# 6.0       17
# 5.0       15
# 15.0       2
# 7.0        2
# 10.0       2
# 9.0        2
# 17.0       1
# 12.0       1
# 44.0       1
# Name: total_male, dtype: int64

# %%
# Handle Null values for values just missing few
train['total_female']       = train['total_female'].fillna(train['total_female'].value_counts().index.tolist()[0])
test['total_female']       = test['total_female'].fillna(test['total_female'].value_counts().index.tolist()[0])

test['total_male'] = test['total_male'].fillna(test['total_male'].value_counts().index.tolist()[0])
train['total_male'] = train['total_male'].fillna(train['total_male'].value_counts().index.tolist()[0])

# %%
train.isnull().sum()
# Out:
# ID                          0
# country                     0
# age_group                   0
# travel_with              1114
# total_female                0
# total_male                  0
# purpose                     0
# main_activity               0
# info_source                 0
# tour_arrangement            0
# package_transport_int       0
# package_accomodation        0
# package_food                0
# package_transport_tz        0
# package_sightseeing         0
# package_guided_tour         0
# package_insurance           0
# night_mainland              0
# night_zanzibar              0
# payment_mode                0
# first_trip_tz               0
# most_impressing           313
# total_cost                  0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            3695 non-null   object
#  4   total_female           4809 non-null   float64
#  5   total_male             4809 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
test['travel_with']
# Out:
# 0                    Spouse
# 1         Friends/Relatives
# 2         Friends/Relatives
# 3         Friends/Relatives
# 4         Friends/Relatives
#                ...
# 1596                    NaN
# 1597    Spouse and Children
# 1598                  Alone
# 1599                  Alone
# 1600                 Spouse
# Name: travel_with, Length: 1601, dtype: object

# %%
#import preprocessing module
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# Cobvert target label to numerical Data
le = LabelEncoder()
'''train['travel_with'] = le.fit_transform(train['travel_with'])
train['most_impressing'] = le.fit_transform(train['most_impressing'])
test['travel_with'] = le.fit_transform(test['travel_with'])
test['most_impressing'] = le.fit_transform(test['most_impressing'])
'''
# Out:
# "train['travel_with'] = le.fit_transform(train['travel_with'])\ntrain['most_impressing'] = le.fit_transform(train['most_impressing'])\ntest['travel_with'] = le.fit_transform(test['travel_with'])\ntest['most_impressing'] = le.fit_transform(test['most_impressing'])\n"

# %%
# to Handle Null values for values more in number.
# let's see how data looks like
# for that Lets plot the distribution of each of these variables, it can give us some hints
#train[['travel_with', 'most_impressing' ]].hist( bins=20, figsize=(8, 8))

# %%
# Handle Null values
'''
train['travel_with']  = train['travel_with'].fillna(train['travel_with'].median())
test['travel_with']  = test['travel_with'].fillna(test['travel_with'].median())
train['most_impressing'] = train['most_impressing'].fillna(train['most_impressing'].median())
test['most_impressing'] = test['most_impressing'].fillna(test['most_impressing'].median())
'''
# Out:
# "\ntrain['travel_with']  = train['travel_with'].fillna(train['travel_with'].median())\ntest['travel_with']  = test['travel_with'].fillna(test['travel_with'].median())\ntrain['most_impressing'] = train['most_impressing'].fillna(train['most_impressing'].median())\ntest['most_impressing'] = test['most_impressing'].fillna(test['most_impressing'].median())\n"

# %%
train.isnull().sum()
# Out:
# ID                          0
# country                     0
# age_group                   0
# travel_with              1114
# total_female                0
# total_male                  0
# purpose                     0
# main_activity               0
# info_source                 0
# tour_arrangement            0
# package_transport_int       0
# package_accomodation        0
# package_food                0
# package_transport_tz        0
# package_sightseeing         0
# package_guided_tour         0
# package_insurance           0
# night_mainland              0
# night_zanzibar              0
# payment_mode                0
# first_trip_tz               0
# most_impressing           313
# total_cost                  0
# dtype: int64

# %%
train.head()
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 3  tour_1002  UNITED KINGDOM     25-44             Spouse           1.0
# 4  tour_1004           CHINA      1-24                NaN           1.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
# 3         1.0            Leisure and Holidays  Wildlife tourism
# 4         0.0            Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement  ... package_transport_tz  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            3695 non-null   object
#  4   total_female           4809 non-null   float64
#  5   total_male             4809 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
#import preprocessing module
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# Cobvert target label to numerical Data
le = LabelEncoder()

# %%
'''# function to preprocess our data from train models

def preprocessing_data(data):

    # Convert the following numerical labels from interger to float
    #float_array = data[["most_impressing"]].values.astype(float)
    
    # categorical features to be onverted to One Hot Encoding
    categ = [
        "country",
        "travel_with",
        "most_impressing",
        "age_group",
        "tour_arrangement",
        "package_transport_int",
        "package_accomodation",
        "package_food",
        "package_sightseeing",
        "package_guided_tour",
        "package_insurance",
    ]
    
    # One Hot Encoding conversion
    data = pd.get_dummies(data, prefix_sep="_", columns=categ)
    
    # Label Encoder conversion
    data["info_source"] = le.fit_transform(data["info_source"])
    data["payment_mode"] = le.fit_transform(data["payment_mode"])
    data["first_trip_tz"] = le.fit_transform(data["first_trip_tz"])
    data['purpose'] = le.fit_transform(data['purpose'])
    data['main_activity'] = le.fit_transform(data['main_activity'])
  
    data['package_transport_tz'] = le.fit_transform(data['package_transport_tz'])
    
    # drop uniquid column
    data = data.drop(["ID"], axis=1)
    
    # scale our data into range of 0 and 1
    scaler = MinMaxScaler(feature_range=(0, 1))
    data = scaler.fit_transform(data)
    
    return data   '''
# Out:
# '# function to preprocess our data from train models\n\ndef preprocessing_data(data):\n\n    # Convert the following numerical labels from interger to float\n    #float_array = data[["most_impressing"]].values.astype(float)\n    \n    # categorical features to be onverted to One Hot Encoding\n    categ = [\n        "country",\n        "travel_with",\n        "most_impressing",\n        "age_group",\n        "tour_arrangement",\n        "package_transport_int",\n        "package_accomodation",\n        "package_food",\n        "package_sightseeing",\n        "package_guided_tour",\n        "package_insurance",\n    ]\n    \n    # One Hot Encoding conversion\n    data = pd.get_dummies(data, prefix_sep="_", columns=categ)\n    \n    # Label Encoder conversion\n    data["info_source"] = le.fit_transform(data["info_source"])\n    data["payment_mode"] = le.fit_transform(data["payment_mode"])\n    data["first_trip_tz"] = le.fit_transform(data["first_trip_tz"])\n    data[\'purpose\'] = le.fi
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            3695 non-null   object
#  4   total_female           4809 non-null   float64
#  5   total_male             4809 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
X_train = train.drop('total_cost', axis=1)
y_train = train['total_cost']

# %%
test.isnull().sum()
# Out:
# ID                         0
# country                    0
# age_group                  0
# travel_with              327
# total_female               0
# total_male                 0
# purpose                    0
# main_activity              0
# info_source                0
# tour_arrangement           0
# package_transport_int      0
# package_accomodation       0
# package_food               0
# package_transport_tz       0
# package_sightseeing        0
# package_guided_tour        0
# package_insurance          0
# night_mainland             0
# night_zanzibar             0
# payment_mode               0
# first_trip_tz              0
# most_impressing          111
# dtype: int64

# %%
X_train.dtypes
# Out:
# ID                        object
# country                    int64
# age_group                  int64
# travel_with               object
# total_female             float64
# total_male               float64
# purpose                   object
# main_activity             object
# info_source               object
# tour_arrangement          object
# package_transport_int      int64
# package_accomodation       int64
# package_food               int64
# package_transport_tz       int64
# package_sightseeing        int64
# package_guided_tour        int64
# package_insurance          int64
# night_mainland           float64
# night_zanzibar           float64
# payment_mode              object
# first_trip_tz              int64
# most_impressing           object
# dtype: object

# %%
X_train.shape
# Out:
# (4809, 22)

# %%
test.dtypes
# Out:
# ID                        object
# country                    int64
# age_group                  int64
# travel_with               object
# total_female             float64
# total_male               float64
# purpose                   object
# main_activity             object
# info_source               object
# tour_arrangement          object
# package_transport_int      int64
# package_accomodation       int64
# package_food               int64
# package_transport_tz       int64
# package_sightseeing        int64
# package_guided_tour        int64
# package_insurance          int64
# night_mainland             int64
# night_zanzibar             int64
# payment_mode              object
# first_trip_tz              int64
# most_impressing           object
# dtype: object

# %%
test.shape
# Out:
# (1601, 22)

# %%
def preprocessing_data(data):    
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    data['age_group'] = le.fit_transform(data['age_group'])
    data['package_transport_int'] = le.fit_transform(data['package_transport_int'])
    data['package_accomodation'] = le.fit_transform(data['package_accomodation'])
    data['package_food'] = le.fit_transform(data['package_food'])
    data['package_transport_tz'] = le.fit_transform(data['package_transport_tz'])
    data['package_sightseeing'] = le.fit_transform(data['package_sightseeing'])
    data['package_guided_tour'] = le.fit_transform(data['package_guided_tour'])
    data['package_insurance'] = le.fit_transform(data['package_insurance'])
    data['first_trip_tz'] = le.fit_transform(data['first_trip_tz'])
    data['country'] = le.fit_transform(data['country'])
    #data['peak_period'] = le.fit_transform(data['peak_period'])
    #data['is_african'] = le.fit_transform(data['is_african'])
    #data['old_folks'] = le.fit_transform(data['old_folks'])

    columns_to_transform = ['tour_arrangement',
                        'travel_with',
                        'purpose',
                        'main_activity',
                        'info_source',
                        'most_impressing',
                        'payment_mode']
    data = pd.get_dummies( data,columns = columns_to_transform,drop_first=True)

    ## convert float dtypes to int
    data["total_female"] = data['total_female'].astype('int')
    data["total_male"] = data['total_male'].astype('int')
    data["night_mainland"] = data['night_mainland'].astype('int')
    data["night_zanzibar"] = data['night_zanzibar'].astype('int')

    # drop uniquid column
    data = data.drop(["ID"], axis=1)
    
   

    return data

# %%
# preprocess the train data 
processed_train = preprocessing_data(X_train)
processed_test = preprocessing_data(test)

# %%
#X_train = processed_train.drop('total_cost', axis=1)
#y_train = processed_train['total_cost']

# %%
processed_train.dtypes
# Out:
# country                                                 int64
# age_group                                               int64
# total_female                                            int64
# total_male                                              int64
# package_transport_int                                   int64
# package_accomodation                                    int64
# package_food                                            int64
# package_transport_tz                                    int64
# package_sightseeing                                     int64
# package_guided_tour                                     int64
# package_insurance                                       int64
# night_mainland                                          int64
# night_zanzibar                                          int64
# first_trip_tz                                           int64
# tour_arrangement_Package Tour                           uint8
# ...

# %%
processed_test.dtypes
# Out:
# country                                                 int64
# age_group                                               int64
# total_female                                            int64
# total_male                                              int64
# package_transport_int                                   int64
# package_accomodation                                    int64
# package_food                                            int64
# package_transport_tz                                    int64
# package_sightseeing                                     int64
# package_guided_tour                                     int64
# package_insurance                                       int64
# night_mainland                                          int64
# night_zanzibar                                          int64
# first_trip_tz                                           int64
# tour_arrangement_Package Tour                           uint8
# ...

# %%
y_train.shape
X_train.shape
# Out:
# (4809, 22)

# %%
# Split train_data
from sklearn.model_selection import train_test_split

X_Train, X_Val, y_Train, y_val = train_test_split(processed_train, y_train,test_size = 0.3, random_state=42)

# %%
print (X_Train.shape, y_Train.shape)
print (X_Val.shape, y_val.shape)
# Out:
# (3366, 49) (3366,)
# (1443, 49) (1443,)

# %%
processed_test.shape
# Out:
# (1601, 49)

# %%
processed_train.shape
# Out:
# (4809, 49)

# %%
y_train.shape
# Out:
# (4809,)

# %%
#importing model  algorithm here
from sklearn.linear_model import LinearRegression

# %%
# creating models
linear_reg=LinearRegression()

# %%
linear_reg.fit(X_Train,y_Train)
# Out:
# LinearRegression()

# %%
# Model evaluation
# import evaluation metrics
from sklearn.metrics import confusion_matrix, accuracy_score
linear_reg_pred=linear_reg.predict(X_Val)

# %%
processed_test.head()
# Out:
#    country  age_group  total_female  total_male  package_transport_int  \
# 0        1          2             1           1                      1
# 1       70          1             0           4                      1
# 2       26          1             3           0                      0
# 3       10          0             2           0                      0
# 4       81          2             2           2                      1
#
#    package_accomodation  package_food  package_transport_tz  \
# 0                     1             1                     1
# 1                     1             0                     0
# 2                     0             0                     0
# 3                     0             0                     0
# 4                     1             1                     1
#
#    package_sightseeing  package_guided_tour  ...  info_source_others  \
# 0                    1                    1  ...                   0
# ...

# %%
processed_train.head()
# Out:
#    country  age_group  total_female  total_male  package_transport_int  \
# 0       89          2             1           1                      0
# 1       99          1             1           0                      0
# 2       99          1             0           1                      0
# 3       99          1             1           1                      0
# 4       13          0             1           0                      0
#
#    package_accomodation  package_food  package_transport_tz  \
# 0                     0             0                     0
# 1                     0             0                     0
# 2                     0             0                     0
# 3                     1             1                     1
# 4                     0             0                     0
#
#    package_sightseeing  package_guided_tour  ...  info_source_others  \
# 0                    0                    0  ...                   0
# ...

# %%
# Get the predicted result for the test Data
test.total_cost = linear_reg.predict(processed_test)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   int64
#  2   age_group              4809 non-null   int64
#  3   travel_with            3695 non-null   object
#  4   total_female           4809 non-null   float64
#  5   total_male             4809 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   int64
#  11  package_accomodation   4809 non-null   int64
#  12  package_food           4809 non-null   int64
#  13  package_transport_tz   4809 non-null   int64
# ...

# %%
X_train.head()
# Out:
#           ID  country  age_group        travel_with  total_female  total_male  \
# 0     tour_0       89          2  Friends/Relatives           1.0         1.0
# 1    tour_10       99          1                NaN           1.0         0.0
# 2  tour_1000       99          1              Alone           0.0         1.0
# 3  tour_1002       99          1             Spouse           1.0         1.0
# 4  tour_1004       13          0                NaN           1.0         0.0
#
#                           purpose     main_activity  \
# 0            Leisure and Holidays  Wildlife tourism
# 1            Leisure and Holidays  Cultural tourism
# 2  Visiting Friends and Relatives  Cultural tourism
# 3            Leisure and Holidays  Wildlife tourism
# 4            Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement  ...  package_food  \
# 0            Friends, relatives      Independent  ...             0
# ...

# %%
# Create submission DataFrame
submission = pd.DataFrame({"ID": test["ID"],
                           "total_cost": test.total_cost })

# %%
submission
# Out:
#              ID    total_cost
# 0        tour_1  1.790586e+07
# 1      tour_100  9.392424e+06
# 2     tour_1001  6.598114e+06
# 3     tour_1006  1.827413e+06
# 4     tour_1009  1.804509e+07
# ...         ...           ...
# 1596   tour_988 -3.110811e+06
# 1597   tour_990  1.766198e+07
# 1598   tour_992 -1.821828e+06
# 1599   tour_996 -3.528700e+06
# 1600   tour_998  4.057598e+06
#
# [1601 rows x 2 columns]

# %%
# Create submission csv file csv file
submission.to_csv('/content/tanzania_tourism_submission.csv', index = False)
